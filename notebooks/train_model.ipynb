# %%
import pandas as pd
import numpy as np 

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, root_mean_squared_error, r2_score
from sklearn.ensemble import RandomForestRegressor

# %%
final_df = pd.read_csv(r"D:\Canadian Business Analysis Project\data\final_processed_data.csv")

threshold = final_df["insolvencies"].quantile(0.4)

final_df["high_risk"] = (final_df["insolvencies"] > threshold).astype(int)

print("Threshold:", threshold)
print(final_df["high_risk"].value_counts())
# Out:
# Threshold: 86.0
# high_risk
# 1    36
# 0    24
# Name: count, dtype: int64

# %%
FEATURES = [
    "closures_lag1",
    "gdp",
    "gdp_qoq_growth",
    "gdp_volatility_4q",
    "cpi",
    "cpi_qoq_growth",
    "sector_code"
]                                      # Dropped CPI_yoy_growth and CPI_volatility_4q since they had no correlation with our output

X = final_df[FEATURES]
y = final_df["high_risk"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

rf = RandomForestClassifier(random_state=42)

param_grid = {
    'n_estimators': [200, 400],
    'max_depth' : [None, 5],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1,2],
    'class_weight': ["balanced"]
}

grid = GridSearchCV (
    rf,
    param_grid=param_grid,
    scoring='recall',
    cv=5,
    n_jobs=-1,
    verbose=1
)

# %%
grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42), n_jobs=-1,
#              param_grid={'class_weight': ['balanced'], 'max_depth': [None, 5],
#                          'min_samples_leaf': [1, 2],
#                          'min_samples_split': [2, 5],
#                          'n_estimators': [200, 400]},
#              scoring='recall', verbose=1)

# %%
best_rf = grid.best_estimator_
print("Best CV recall(1): " , grid.best_score_)
# Out:
# Best CV recall(1):  0.8800000000000001

# %%
from sklearn.metrics import confusion_matrix, classification_report
preds = best_rf.predict(X_test)

print("Confusion Matrix:", confusion_matrix(y_test, preds))

print("Classification Report:")
print(classification_report(y_test, preds))
# Out:
# Confusion Matrix: [[ 4  3]
#  [ 1 10]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.57      0.67         7
#            1       0.77      0.91      0.83        11
#
#     accuracy                           0.78        18
#    macro avg       0.78      0.74      0.75        18
# weighted avg       0.78      0.78      0.77        18

# %%
from sklearn.metrics import roc_auc_score

probs = best_rf.predict_proba(X_test)[:, 1]
print("ROC AUC:", roc_auc_score(y_test, probs))
# Out:
# ROC AUC: 0.8051948051948052

# %%
importance = pd.Series(
    best_rf.feature_importances_,
    index=FEATURES
).sort_values(ascending=False)

print("\nFeature Importance (RF)")
print(importance)
# Out:
# Feature Importance (RF)
# sector_code          0.264126
# gdp_qoq_growth       0.241560
# gdp                  0.222975
# gdp_volatility_4q    0.149316
# closures_lag1        0.066445
# cpi                  0.030408
# cpi_qoq_growth       0.025168
# dtype: float64

# %%
final_df["risk_prob"] = best_rf.predict_proba(final_df[FEATURES])[:, 1]

THRESHOLD = 0.4
final_df["predicted_risk"] = (final_df["risk_prob"] >= THRESHOLD).astype(int)

# %%
sector_risk = (
    final_df
    .groupby(["sector_code", "sector"])
    .agg(
        avg_risk_prob = ("risk_prob", "mean"),
        high_risk_rate = ("predicted_risk", "mean"),
        avg_insolvencies=("insolvencies", "mean")
    )
    .reset_index()
    .sort_values("avg_risk_prob", ascending=False)
)

# %%
sector_risk["risk_label"] = pd.cut(
    sector_risk["avg_risk_prob"],
    bins=[0, 0.4, 0.7, 1.0],
    labels = ["Low Risk", "Medium Risk", "High Risk"]
)

# %%
sector_risk
# Out:
#     sector_code                                             sector  \
# 4            31                                      Manufacturing
# 3            23                                       Construction
# 10           53                 Real Estate and Rental and Leasing
# 18           81      Other Services (except Public Administration)
# 5            41                                    Wholesale Trade
# 7            48                     Transportation and Warehousing
# 17           72                    Accommodation and Food Services
# 11           54    Professional, Scientific and Technical Services
# 6            44                                       Retail Trade
# 13           56  Administrative and Support, Waste Management a...
# 16           71                 Arts, Entertainment and Recreation
# 8            51                Information and Cultural Industries
# 12           55            Management of Companies and Enterprises
# 9            52                              Finance and Insurance
# 15           62                  Health Care and Social Assistance
# 19           91                              Public Administration
# 2            22                                          Utilities
# 14           61                               Educational Services
# 0            11         Agriculture, Forestry, Fishing and Hunting
# 1            21                  Mining and Oil and Gas Extraction
#
#     avg_risk_prob  high_risk_rate  avg_insolvencies   risk_label
# 4        0.951667        1.000000        290.000000    High Risk
# 3        0.913333        1.000000        498.333333    High Risk
# 10       0.901667        1.000000        123.000000    High Risk
# 18       0.880000        1.000000        260.666667    High Risk
# 5        0.876667        1.000000        186.000000    High Risk
# 7        0.871667        1.000000        302.333333    High Risk
# 17       0.793333        1.000000        574.333333    High Risk
# 11       0.755000        1.000000        275.666667    High Risk
# 6        0.740000        1.000000        439.333333    High Risk
# 13       0.721667        0.666667        186.666667    High Risk
# 16       0.685000        1.000000         99.000000  Medium Risk
# 8        0.595000        0.666667         81.333333  Medium Risk
# 12       0.551667        0.666667         93.000000  Medium Risk
# 9        0.441667        0.333333         51.333333  Medium Risk
# 15       0.373333        0.666667         89.666667     Low Risk
# 19       0.295000        0.333333         10.000000     Low Risk
# 2        0.258333        0.000000          6.666667     Low Risk
# 14       0.206667        0.000000         43.666667     Low Risk
# 0        0.128333        0.000000         66.333333     Low Risk
# 1        0.078333        0.000000         21.000000     Low Risk

# %%
sector_risk.to_csv(r'D:\Canadian Business Analysis Project\data\final_trained_data.csv', index = False)
